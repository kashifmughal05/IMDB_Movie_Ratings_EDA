# %% [markdown]
# Subject: IMDB Movie Ratings EDA\
# Authored by: Hafiz Muhammad Kashif\
# [LinkedIn](https://www.linkedin.com/in/hafiz-muhammad-kashif-83a657261/)\
# [Kaggle](https://www.kaggle.com/kashif20/)\
# [GitHub](https://github.com/kashifmughal05/)

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb_5000_movies.csv')

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# Check the null values
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# As we can see that columns ('homepage' and 'tagline') have maximum numbers of null values, therefore, I will drop these two columns
#
# Here I will also drop two rows having null values in the column 'runtime'

# %%
df.drop(columns= ['homepage', 'tagline'], inplace=True)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
# Separate the value of 'year' from 'release_date'
df['year'] = df['release_date'].str.split('-').str[0]

# %%
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
# Check the dupliacte values
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.799000e+03    4799.000000  4799.000000  4.799000e+03  4799.000000
# mean   2.906593e+07   56899.920192    21.509884  8.232920e+07   106.903105
# std    4.073251e+07   88236.500208    31.824074  1.629076e+08    22.561305
# min    0.000000e+00       5.000000     0.000372  0.000000e+00     0.000000
# 25%    8.000000e+05    9012.500000     4.685547  0.000000e+00    94.000000
# 50%    1.500000e+07   14623.000000    12.929525  1.918402e+07   103.000000
# 75%    4.000000e+07   58461.500000    28.350728  9.295652e+07   118.000000
# max    3.800000e+08  447027.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4799.000000   4799.000000
# mean       6.094186    690.789123
# std        1.188340   1234.941795
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    236.000000
# 75%        6.800000    737.500000
# ...

# %% [markdown]
# ### Display Title of the Movies having Runtime Greater than or equal to 180 Minutes

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
top10_movies_by_runtime = df[df['runtime'] >= 180][['title','runtime']].reset_index().drop(columns='index')
top10_movies_by_runtime
# Out:
#                                             title  runtime
# 0                                       King Kong    187.0
# 1                                         Titanic    194.0
# 2                                    Pearl Harbor    183.0
# 3                         The Wolf of Wall Street    180.0
# 4   The Lord of the Rings: The Return of the King    201.0
# 5                                      Wyatt Earp    191.0
# 6                                  The Green Mile    189.0
# 7                               Gods and Generals    214.0
# 8                                      Grindhouse    191.0
# 9                                           Nixon    192.0
# 10                                  Heaven's Gate    219.0
# 11                                      Cleopatra    248.0
# 12                                            JFK    189.0
# 13                                       Magnolia    188.0
# 14                                      Malcolm X    202.0
# ...

# %% [markdown]
# ### Top 10 Years by Highest Average voting?

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
top10_years = df.groupby('year')['vote_count'].mean().sort_values(ascending=False)
a = top10_years.head(10)
a = pd.DataFrame(a)
a
# Out:
#        vote_count
# year
# 1942  1413.500000
# 1975  1322.500000
# 1957  1310.000000
# 2016  1146.384615
# 2013  1135.939394
# 2012  1105.668269
# 2014  1050.544304
# 2015   983.018692
# 1937   962.500000
# 1939   951.000000

# %%
sns.barplot(x = 'year', y = 'vote_count', data = a)
plt.title('Top 10 years by votes')
plt.xlabel('Year')
plt.ylabel('Number of Votes')
plt.show()

# %% [markdown]
# ### Top 10 Years by Revenue

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
b = df.groupby('year')['revenue'].mean().sort_values(ascending=False)
b = b.head(10)
b = pd.DataFrame(b)
b
# Out:
#            revenue
# year
# 1939  1.478438e+08
# 2016  1.390496e+08
# 1942  1.389548e+08
# 1990  1.332335e+08
# 2012  1.160659e+08
# 1992  1.104972e+08
# 1975  1.090829e+08
# 1994  1.077955e+08
# 1973  1.066211e+08
# 2015  1.064253e+08

# %%
sns.barplot(x = 'year', y = 'revenue', data = b)
plt.title('Top 10 Years by Revenue')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ### Find the Average Rating for each Director

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %% [markdown]
# ### Display Top 10 Lengthy Movies Titles and Runtime

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
c = df.nlargest(10, 'runtime')[['title', 'runtime']].set_index('title')
c
# Out:
#                              runtime
# title
# Carlos                         338.0
# The Company                    276.0
# Gettysburg                     254.0
# Cleopatra                      248.0
# Hamlet                         242.0
# Emma                           240.0
# Gone with the Wind             238.0
# Once Upon a Time in America    229.0
# Woodstock                      225.0
# Heaven's Gate                  219.0

# %%
sns.barplot(x = 'runtime', y = c.index, data = c)
plt.title('Top 10 Lengthy Movies')
plt.xlabel('Runtime')
plt.ylabel('Title')
plt.show()

# %% [markdown]
# ### Find Most Popular Movie Title by Revenue

# %%
df[df['revenue'] == df['revenue'].max()]
# Out:
#       budget                                             genres     id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#     title  vote_average  vote_count  year
# 0  Avatar           7.2       11800  2009

# %% [markdown]
# ### Display Top 10 Highest Rated Movies Titles and their Directors

# %% [markdown]
# ### Display Top 10 Highest Revenue Movie Titles

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
d = df.nlargest(10, 'revenue')[['title', 'revenue']].set_index('title')
d
# Out:
#                                revenue
# title
# Avatar                      2787965087
# Titanic                     1845034188
# The Avengers                1519557910
# Jurassic World              1513528810
# Furious 7                   1506249360
# Avengers: Age of Ultron     1405403694
# Frozen                      1274219009
# Iron Man 3                  1215439994
# Minions                     1156730962
# Captain America: Civil War  1153304495

# %%
sns.barplot(x = 'revenue', y = 'title', data = d)
plt.title('Top 10 Movies by Revenue')
plt.xlabel('Revenue')
plt.ylabel('Title')
plt.show()

# %% [markdown]
# ### Find Average Rating of Movies Year Wise

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
df.groupby('year')['vote_average'].mean().sort_values(ascending=False)
# Out:
# year
# 1927    8.000000
# 1957    7.950000
# 1960    7.866667
# 1934    7.700000
# 1939    7.666667
#           ...
# 2012    5.909615
# 2016    5.833654
# 2015    5.612150
# 1933    5.600000
# 2014    5.571308
# Name: vote_average, Length: 90, dtype: float64

# %% [markdown]
# ### Does Rating Affect the Revenue?

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
sns.scatterplot(x='revenue', y='vote_average', data=df)
# Out:
# <Axes: xlabel='revenue', ylabel='vote_average'>

# %% [markdown]
# Rating does not have significant impact on revenue

# %% [markdown]
# ### Classify Movies based on Ratings (Excellent, Good, Average)

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year'],
#       dtype='object')

# %%
def rating(rating):
    if rating >= 7.0:
        return 'Excellent'
    elif rating >= 6.0:
        return 'Good'
    else:
        return 'Average'

# %%
df['rating_category'] = df['vote_average'].apply(rating)

# %%
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %% [markdown]
# ### Count Number of Action Movies

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'year', 'rating_category'],
#       dtype='object')

# %%
df['genres'].dtype
# Out:
# dtype('O')

# %%
df[df['genres'].str.contains('Action', case=False)]
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4734          0  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...  270554
# 4769          0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...   69382
# 4772      31192  [{"id": 18, "name": "Drama"}, {"id": 28, "name...   42151
# 4778          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...   38780
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
#
# ...

# %%
len(df[df['genres'].str.contains('Action', case=False)])
# Out:
# 1154

# %% [markdown]
# There are 1154 Action Movies

# %% [markdown]
# ### Find Unique Values from Genre

# %%
df['genres']
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4798    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                   []
# 4802                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4799, dtype: object

# %%
df['Genre'] = df['genres'].str.split(':').str[2].str.split(',').str[0].str.replace('}', ' ').str.replace(']', ' ')
df['Genre']
# Out:
# 0              "Action"
# 1           "Adventure"
# 2              "Action"
# 3              "Action"
# 4              "Action"
#               ...
# 4798           "Action"
# 4799           "Comedy"
# 4800           "Comedy"
# 4801                 NaN
# 4802     "Documentary"
# Name: Genre, Length: 4799, dtype: object

# %%
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
df['Genre'].isnull().sum()
# Out:
# 27

# %%
df['Genre'].fillna(df['Genre'].mode()[0], inplace=True)

# %%
df['Genre'].isnull().sum()
# Out:
# 0

# %%
df['Genre'].unique()
# Out:
# array([' "Action" ', ' "Adventure" ', ' "Fantasy" ', ' "Animation" ',
#        ' "Science Fiction" ', ' "Drama" ', ' "Thriller" ', ' "Family" ',
#        ' "Action"  ', ' "Science Fiction"  ', ' "Comedy" ',
#        ' "Fantasy"  ', ' "History" ', ' "War" ', ' "Adventure"  ',
#        ' "Comedy"  ', ' "Western" ', ' "Drama"  ', ' "Romance" ',
#        ' "Crime" ', ' "Animation"  ', ' "War"  ', ' "Mystery" ',
#        ' "Horror" ', ' "Documentary" ', ' "Thriller"  ', ' "Music" ',
#        ' "Horror"  ', ' "Western"  ', ' "Music"  ', ' "Romance"  ',
#        ' "Documentary"  ', ' "Family"  ', ' "History"  ', ' "TV Movie" ',
#        ' "Crime"  ', ' "Foreign" '], dtype=object)

# %% [markdown]
# These are the unique values from Genre

# %%
df['Genre'].nunique()
# Out:
# 37

# %% [markdown]
# ### How many Films of each Genre were made?

# %%
df['Genre'].value_counts()
# Out:
# Genre
#  "Drama"                864
#  "Comedy"               760
#  "Action"               733
#  "Drama"                369
#  "Adventure"            326
#  "Comedy"               282
#  "Horror"               236
#  "Crime"                194
#  "Thriller"             171
#  "Animation"            121
#  "Fantasy"              111
#  "Romance"              101
#  "Science Fiction"       82
#  "Documentary"           66
#  "Horror"                64
#  "Family"                49
#  "Mystery"               41
#  "Music"                 31
#  "History"               24
#  "Thriller"              23
#  "War"                   22
#  "Documentary"           21
#  "Action"                21
#  "Western"               18
#  "Science Fiction"       14
#  "Adventure"             13
#  "Western"                9
#  "Family"                 7
#  "Fantasy"                6
#  "Romance"                5
#  "TV Movie"               4
#  "Music"                  3
#  "War"                    2
# ...

# %% [markdown]
# # End of the Notebook
